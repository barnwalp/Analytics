# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path = os.path.join(os.getenv('win_home'), 'github_repo', 'datasets', 'iocl')
os.chdir(path)
df = pd.read_csv('hourly_tank_report.csv')
df.head()
# Out:
#       DATE AND TIME  TANK PRODUCT  OPENING STOCK(Ltr.)  CLOSING STOCK(Ltr.)  \
# 0  09-01-2021 10:30     1      MS              8131.31              8033.09
# 1  09-01-2021 10:30     2     HSD              3384.07              3318.85
# 2  09-01-2021 10:00     1      MS              8214.82              8131.31
# 3  09-01-2021 10:00     2     HSD              3531.93              3384.07
# 4  09-01-2021 09:30     1      MS              8326.43              8214.82
#
#    RECEIPT(Ltr.)  DIP SALE(Ltr.)  TRANSACTION SALE(Ltr.)  VARIATION(Ltr.)
# 0              0           98.22                  100.36             2.14
# 1              0           65.22                   67.83             2.61
# 2              0           83.51                   85.35             1.84
# 3              0          147.86                  148.36             0.50
# 4              0          111.61                  109.77            -1.84

# %%
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='DATE AND TIME', y='OPENING STOCK(Ltr.)', hue='PRODUCT')
# Out:
# <AxesSubplot:xlabel='DATE AND TIME', ylabel='OPENING STOCK(Ltr.)'>

# %%
df_opening = df[df['OPENING STOCK(Ltr.)'] <=3000]
df_closing = df[df['CLOSING STOCK(Ltr.)'] <=2500]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 358 to 11081
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE AND TIME           522 non-null    object
#  1   TANK                    522 non-null    int64
#  2   PRODUCT                 522 non-null    object
#  3   OPENING STOCK(Ltr.)     522 non-null    float64
#  4   CLOSING STOCK(Ltr.)     522 non-null    float64
#  5   RECEIPT(Ltr.)           522 non-null    int64
#  6   DIP SALE(Ltr.)          522 non-null    float64
#  7   TRANSACTION SALE(Ltr.)  522 non-null    float64
#  8   VARIATION(Ltr.)         522 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 40.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327 entries, 360 to 11081
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   DATE AND TIME           327 non-null    object
#  1   TANK                    327 non-null    int64
#  2   PRODUCT                 327 non-null    object
#  3   OPENING STOCK(Ltr.)     327 non-null    float64
#  4   CLOSING STOCK(Ltr.)     327 non-null    float64
#  5   RECEIPT(Ltr.)           327 non-null    int64
#  6   DIP SALE(Ltr.)          327 non-null    float64
#  7   TRANSACTION SALE(Ltr.)  327 non-null    float64
#  8   VARIATION(Ltr.)         327 non-null    float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 25.5+ KB

# %%
# Out:
# <AxesSubplot:xlabel='DATE AND TIME', ylabel='OPENING STOCK(Ltr.)'>
